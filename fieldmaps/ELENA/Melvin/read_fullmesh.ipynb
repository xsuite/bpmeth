# %%
from read import *
import sympy as sp

# %%
# The field at 0,0,0 in FS coordinates for the magnet is 5.3810473e-07
nominalfield = 5.3810473e-07

# %%
# Data for the fringe only
data = np.loadtxt("BEM_analyzer/eval/elena/fullmagnet/evaluate_h_3_p_3.csv", skiprows=1, delimiter=',')
localpos = np.loadtxt("BEM_analyzer/eval/elena/fullmagnet/localpos.csv", skiprows=1, delimiter=',')

# %%
elenamagnet = Magnet(data, localpos, nominalfield)

# %%
elenamagnet.plot("By")
# Out:
# /home/silke/miniforge3/envs/xsuite/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
